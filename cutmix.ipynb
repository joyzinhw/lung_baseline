# %%
import os
import random
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import gc 
import time
import copy
import math
from torchvision.transforms import RandAugment

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchinfo
from torchinfo import summary
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import WeightedRandomSampler
from torchvision import transforms
from torchvision import models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, accuracy_score, f1_score, cohen_kappa_score, roc_auc_score, precision_score, recall_score
from PIL import Image

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# %%
base_path = 'LungHist700_combined/data/'
csv_path = base_path + 'data.csv'
images_base = base_path + 'images/' 

batch_size = 32
num_epochs = 100
learning_rate = 3e-4
random_seed = 42

def seed_everything(seed):
    random.seed(seed)

    os.environ['PYTHONHASHSEED'] = str(seed)

    np.random.seed(seed)

    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    torch.use_deterministic_algorithms(True)


def seed_worker(worker_id):

    worker_seed = torch.initial_seed() % 2**32

    np.random.seed(worker_seed)
    random.seed(worker_seed)

seed_everything(random_seed)

g = torch.Generator()
g.manual_seed(random_seed)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Dispositivo em uso: {device}\n")

full_df = pd.read_csv(csv_path)
superclass_map = {'aca': 0, 'ssc': 1, 'scc': 1, 'nor': 2}
full_df['label'] = full_df['superclass'].map(superclass_map)

print("Dados carregados e mapeados com sucesso!")
print("Total de linhas:", len(full_df))
print("Colunas:", full_df.columns.tolist())
print("Exemplo das 5 primeiras linhas:\n", full_df.head())
print("Distribuição de resolução:\n", full_df['resolution'].value_counts())


def get_dataframe_no_loss(df_input):
    return df_input.sample(frac=1, random_state=random_seed).reset_index(drop=True)

print("Função de processamento de dados atualizada!")
# Out:
# Dispositivo em uso: cpu
#
# Dados carregados e mapeados com sucesso!
# Total de linhas: 691
# Colunas: ['superclass', 'subclass', 'resolution', 'image_id', 'patient_id', 'label']
# Exemplo das 5 primeiras linhas:
#    superclass subclass resolution  image_id  patient_id  label
# 0        aca       bd        40x       901           1      0
# 1        aca       bd        40x       902           1      0
# 2        aca       bd        40x       903           1      0
# 3        aca       bd        40x       904           1      0
# 4        aca       bd        40x       905           1      0
# Distribuição de resolução:
#  resolution
# 20x    359
# 40x    332
# Name: count, dtype: int64
# Função de processamento de dados atualizada!

# %%
class LungHistDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.df = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        superclass = row['superclass'] 
        image_id = row['image_id']
        resolution = row['resolution']
        subclass = row['subclass'] if not pd.isna(row['subclass']) else ""

        folder_name = superclass
        if superclass == 'scc':
            folder_name = 'ssc' 
        
        class_dir = os.path.join(self.root_dir, folder_name)

        potential_filenames = [
            f"{image_id}.jpg",                                      
            f"{superclass}_{subclass}_{resolution}_{image_id}.jpg", 
            f"{superclass}_{resolution}_{image_id}.jpg",            
            f"{image_id}.png",                                     
            f"{superclass}_{subclass}_{resolution}_{image_id}.png"
        ]
        
        img_path = None
        for fname in potential_filenames:
            full_path = os.path.join(class_dir, fname)
            if os.path.exists(full_path):
                img_path = full_path
                break
        
        if img_path is None and os.path.exists(class_dir):
            import glob
            search_pattern = os.path.join(class_dir, f"*{image_id}.*")
            found_files = glob.glob(search_pattern)
            if found_files:
                img_path = found_files[0]

        try:
            if img_path is None:
                raise FileNotFoundError(f"Imagem com ID {image_id} não encontrada em {class_dir}")
            image = Image.open(img_path).convert("RGB")
        except Exception as e:
            image = Image.new('RGB', (224, 224))
            
        label = row['label']
        if self.transform:
            image = self.transform(image)
        return image, label

print("Classe Dataset definida com sucesso!")
# Out:
# Classe Dataset definida com sucesso!

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),

    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.ToTensor(),

    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])


val_test_transform = transforms.Compose([
    transforms.Resize(256),        
    transforms.CenterCrop(224),  
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

def cutmix(data, targets, alpha=1.0):
    lam = np.random.beta(alpha, alpha)
    batch_size = data.size(0)
    index = torch.randperm(batch_size, device=data.device)
    shuffled_data = data[index]
    shuffled_targets = targets[index]
    
    bbx1, bby1, bbx2, bby2 = rand_bbox(data.size(), lam)
    data[:, :, bby1:bby2, bbx1:bbx2] = shuffled_data[:, :, bby1:bby2, bbx1:bbx2]
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (data.size(-1) * data.size(-2)))
    
    return data, targets, shuffled_targets, lam

def rand_bbox(size, lam):
    W = size[3]
    H = size[2]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2
    
print("✅ CutMix configurados com sucesso (224x224).")
# Out:
# ✅ RandAugment + CutMix configurados com sucesso (224x224).

# %%
rand_idx = random.randint(0, len(full_df) - 1)
demo_ds = LungHistDataset(full_df, root_dir=images_base, transform=None)
original_img, label_idx = demo_ds[rand_idx]

idx_to_class = {0: 'ACA', 1: 'SCC', 2: 'NOR'}
class_name = idx_to_class[label_idx]

rand_idx_2 = random.randint(0, len(full_df) - 1)
img_b, label_b_idx = demo_ds[rand_idx_2]
class_name_b = idx_to_class[label_b_idx]

demo_augmentations = [
    ("RandomResizedCrop", transforms.RandomResizedCrop(224, scale=(0.8, 1.0))),

    ("RandomRotation 15°", transforms.Compose([transforms.Resize((224, 224)), transforms.RandomRotation(15)])),
    ("Flip Horizontal", transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(p=1.0)
    ])),

    ("Flip Vertical", transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomVerticalFlip(p=1.0)
    ])),
]

preprocess = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])

tensor_a = preprocess(original_img).unsqueeze(0)
tensor_b = preprocess(img_b).unsqueeze(0)

lam = np.random.beta(1.0, 1.0)
bbx1, bby1, bbx2, bby2 = rand_bbox(tensor_a.size(), lam)

tensor_cutmix = tensor_a.clone()
tensor_cutmix[:, :, bbx1:bbx2, bby1:bby2] = tensor_b[:, :, bbx1:bbx2, bby1:bby2]

cutmix_img = transforms.ToPILImage()(tensor_cutmix.squeeze(0))

plt.figure(figsize=(20, 5))

plt.subplot(1, 6, 1)
plt.imshow(original_img)
plt.title(f"ORIGINAL ({class_name})", fontweight='bold')
plt.axis('off')

for i, (name, transform_func) in enumerate(demo_augmentations):
    aug_img = transform_func(original_img)
    
    plt.subplot(1, 6, i + 2)
    plt.imshow(aug_img)
    plt.title(name, fontsize=10)
    plt.axis('off')

plt.subplot(1, 6, 6)
plt.imshow(cutmix_img)
plt.title(f"CutMix ({class_name_b})", fontsize=10, fontweight='bold')
plt.axis('off')

img_id = full_df.iloc[rand_idx]['image_id']

plt.suptitle(
    f"DATA AUGMENTATION UTILIZADA NO TREINO | ID: {img_id}",
    fontsize=14
)

plt.tight_layout()
plt.show()

# %%
# ====================== PARTE 6: FUNÇÃO DE ESTATÍSTICAS ======================
def print_stats_table(df_name, train_df, val_df, test_df):
    c_train = train_df['label'].value_counts().to_dict()
    c_val   = val_df['label'].value_counts().to_dict()
    c_test  = test_df['label'].value_counts().to_dict()
    idx_to_class = {0: 'ACA', 1: 'SCC', 2: 'NOR'}
    
    print(f"\nCONJUNTO DE DADOS: {df_name}")
    print("-" * 42)
    print(f"{'CLASSE':<8} | {'TREINO':<8} | {'VALIDAÇÃO':<8} | {'TESTE':<8}")
    print("-" * 42)
    for idx in range(3): 
        name = idx_to_class[idx]
        print(f"{name:<8} | {c_train.get(idx, 0):<8} | {c_val.get(idx, 0):<8} | {c_test.get(idx, 0):<8}")
    print("-" * 42 + "\n")

print("Função print_stats_table definida com sucesso!")
# Out:
# Função print_stats_table definida com sucesso!

# %%
def make_weighted_sampler(df_train, label_col='label', seed=42):

    class_counts = df_train[label_col].value_counts().sort_index().values

    # pesos inversos
    class_weights = 1.0 / class_counts

    sample_weights = [
        class_weights[label]
        for label in df_train[label_col]
    ]

    # generator fixo
    g = torch.Generator()
    g.manual_seed(seed)

    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True,
        generator=g
    )

    return sampler

print("Função make_weighted_sampler definida com sucesso!")
# Out:
# Função make_weighted_sampler definida com sucesso!

# %%
def get_reproducible_ids(df, resolution):

    if resolution == '20x':
        train_ids = [2,3,4,5,7,8,12,14,15,16,17,18,20,21,23,24,25,26,28,29,30,33,36,37,38,39,41,42,45]
        val_ids   = [1,6,27,32,44]
        test_ids  = [9,13,31,40]

    elif resolution == '40x':
        train_ids = [2,6,8,9,10,12,13,14,16,18,19,21,22,24,28,29,31,33,34,35,36,38,40,44]
        val_ids   = [1,4,17,26,30,37,45]
        test_ids  = [11,15,20,25,32,43]

    else:
        raise ValueError("Resolution deve ser '20x' ou '40x'")

    train_df = df[df['patient_id'].isin(train_ids)]
    val_df   = df[df['patient_id'].isin(val_ids)]
    test_df  = df[df['patient_id'].isin(test_ids)]

    return train_df, val_df, test_df



def process_resolution(res):

    print(f"\n====================== {res.upper()} ======================")

   
    df_res = full_df[
        (full_df['resolution'] == res) &
        (full_df['superclass'].isin(['aca', 'nor', 'scc']))
    ].reset_index(drop=True)

    print(f"Dataset {res}: {len(df_res)} imagens")

  
    df_res = get_dataframe_no_loss(df_res)

    
    train_df, val_df, test_df = get_reproducible_ids(df_res, res)

    
    train_df = train_df.reset_index(drop=True)
    val_df   = val_df.reset_index(drop=True)
    test_df  = test_df.reset_index(drop=True)

  
    print("\n📊 Classes por split:")
    for name, df_split in [("train", train_df), ("val", val_df), ("test", test_df)]:
        print(f"\n{name.upper()}")
        print(df_split["superclass"].value_counts())

    print("\n🔎 Verificação de leakage:")
    print("train ∩ val :", set(train_df['patient_id']) & set(val_df['patient_id']))
    print("train ∩ test:", set(train_df['patient_id']) & set(test_df['patient_id']))
    print("val ∩ test :", set(val_df['patient_id']) & set(test_df['patient_id']))

    train_sampler = make_weighted_sampler(train_df, label_col='label')

    train_ds = LungHistDataset(train_df, images_base, transform=train_transform)
    val_ds   = LungHistDataset(val_df,   images_base, transform=val_test_transform)
    test_ds  = LungHistDataset(test_df,  images_base, transform=val_test_transform)

    train_loader = DataLoader(
        train_ds,
        batch_size=batch_size,
        sampler=train_sampler,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g,
        persistent_workers=True
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g,
        persistent_workers=True
    )

    test_loader = DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g,
        persistent_workers=True
    )

    print_stats_table(f"{res.upper()} (SPLIT FIXO POR PACIENTE)", train_df, val_df, test_df)

    return train_loader, val_loader, test_loader



train_loader_20x, val_loader_20x, test_loader_20x = process_resolution('20x')
train_loader_40x, val_loader_40x, test_loader_40x = process_resolution('40x')
# Out:
# ====================== 20X ======================
# Dataset 20x: 359 imagens
#
# 📊 Classes por split:
#
# TRAIN
# superclass
# aca    109
# scc    102
# nor     52
# Name: count, dtype: int64
#
# VAL
# superclass
# aca    19
# scc    15
# nor    14
# Name: count, dtype: int64
#
# TEST
# superclass
# nor    19
# aca    18
# scc    11
# Name: count, dtype: int64
#
# 🔎 Verificação de leakage:
# train ∩ val : set()
# train ∩ test: set()
# val ∩ test : set()
#
# CONJUNTO DE DADOS: 20X (SPLIT FIXO POR PACIENTE)
# ------------------------------------------
# CLASSE   | TREINO   | VALIDAÇÃO | TESTE
# ------------------------------------------
# ACA      | 109      | 19       | 18
# SCC      | 102      | 15       | 11
# NOR      | 52       | 14       | 19
# ------------------------------------------
#
#
# ====================== 40X ======================
# Dataset 40x: 332 imagens
#
# 📊 Classes por split:
#
# TRAIN
# superclass
# aca    101
# scc     96
# nor     39
# Name: count, dtype: int64
#
# VAL
# superclass
# aca    16
# scc    16
# nor    14
# Name: count, dtype: int64
#
# TEST
# superclass
# scc    20
# aca    17
# nor    13
# Name: count, dtype: int64
#
# 🔎 Verificação de leakage:
# train ∩ val : set()
# train ∩ test: set()
# val ∩ test : set()
#
# CONJUNTO DE DADOS: 40X (SPLIT FIXO POR PACIENTE)
# ------------------------------------------
# CLASSE   | TREINO   | VALIDAÇÃO | TESTE
# ------------------------------------------
# ACA      | 101      | 16       | 17
# SCC      | 96       | 16       | 20
# NOR      | 39       | 14       | 13
# ------------------------------------------

# %%
def get_model(model_name, num_classes=3, feature_extract=True):
    model = None
    if model_name == 'resnet50':
        weights = models.ResNet50_Weights.DEFAULT
        model = models.resnet50(weights=weights)
        if feature_extract:
            for param in model.parameters(): param.requires_grad = False
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(0.5), nn.Linear(num_ftrs, num_classes))

    elif model_name == 'efficientnet_b0':
        weights = models.EfficientNet_B0_Weights.DEFAULT
        model = models.efficientnet_b0(weights=weights)
        if feature_extract:
            for param in model.parameters(): param.requires_grad = False
        num_ftrs = model.classifier[1].in_features 
        model.classifier = nn.Sequential(nn.Dropout(0.3), nn.Linear(num_ftrs, num_classes))

    elif model_name == 'efficientnet_b3':
        weights = models.EfficientNet_B3_Weights.DEFAULT 
        model = models.efficientnet_b3(weights=weights)
        if feature_extract:
            for param in model.parameters(): param.requires_grad = False
        num_ftrs = model.classifier[1].in_features
        model.classifier = nn.Sequential(nn.Dropout(0.4), nn.Linear(num_ftrs, num_classes))
        
    elif model_name == 'densenet121':
        weights = models.DenseNet121_Weights.DEFAULT
        model = models.densenet121(weights=weights)
        if feature_extract:
            for param in model.parameters(): param.requires_grad = False
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Sequential(nn.Dropout(0.5), nn.Linear(num_ftrs, num_classes))
    
    return model.to(device)

# %%
#config

def train_model(
    model,
    dataloaders,
    criterion,
    num_epochs=100,
    save_name='best_model.pth',
    model_name='MODEL',
    cutmix_prob=0.0,

   
    learning_rate=3e-4,
    weight_decay=1e-4,

    optimizer_name="adamw",
    scheduler_name="cosine",

    scheduler_step_size=10,
    scheduler_gamma=0.1,
    scheduler_t_max=35,
    min_learning_rate=1e-6,

    
    early_stopping_patience=20
):

    since = time.time()

    val_acc_history = []
    train_loss_history = []
    val_loss_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    epochs_no_improve = 0  

  
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=learning_rate,
        weight_decay=weight_decay
    )

    if scheduler_name == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer,
            T_max=scheduler_t_max,
            eta_min=min_learning_rate
        )
    elif scheduler_name == "step":
        scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer,
            step_size=scheduler_step_size,
            gamma=scheduler_gamma
        )
    elif scheduler_name == "plateau":
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=scheduler_gamma,
            patience=5
        )
    else:
        scheduler = None

    print(f"\n🚀 START TRAINING {model_name}")
    print(f"🧠 Early Stopping patience = {early_stopping_patience}")

   
    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1:02d}/{num_epochs}')

        epoch_val_loss = None
        improved = False

        for phase in ['train', 'val']:
            model.train() if phase == 'train' else model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):

                    # CUTMIX
                    if phase == 'train' and np.random.rand() < cutmix_prob:
                        inputs, targets_a, targets_b, lam = cutmix(inputs, labels, alpha=1.0)

                        inputs = inputs.to(device)
                        targets_a = targets_a.to(device)
                        targets_b = targets_b.to(device)

                        outputs = model(inputs)
                        loss = (
                            criterion(outputs, targets_a) * lam +
                            criterion(outputs, targets_b) * (1. - lam)
                        )
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print(f"  {phase.upper()} → Loss: {epoch_loss:.4f} | Acc: {epoch_acc:.4f}")

            if phase == 'train':
                train_loss_history.append(epoch_loss)
            else:
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc.item())
                epoch_val_loss = epoch_loss

                # BEST MODEL
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                    torch.save(model.state_dict(), save_name)
                    print(f"  BEST MODEL SAVED | Acc: {best_acc:.4f}")
                    improved = True

        if improved:
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            print(f" No improvement for {epochs_no_improve} epochs")

        if epochs_no_improve >= early_stopping_patience:
            print(f"\n EARLY STOPPING TRIGGERED (patience={early_stopping_patience})")
            break

        if scheduler:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(epoch_val_loss)
            else:
                scheduler.step()

        print(f"    LR atual: {optimizer.param_groups[0]['lr']:.6f}")

    time_elapsed = time.time() - since

    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f' Best Val Acc: {best_acc:.4f}')

    model.load_state_dict(best_model_wts)

    history = {
        'train_loss': train_loss_history,
        'val_loss': val_loss_history,
        'val_acc': val_acc_history
    }

    return model, history, best_acc

# %%
# MODELS 
model_names_check = ['resnet50', 'efficientnet_b0', 'efficientnet_b3', 'densenet121']

sample_images, sample_labels = next(iter(train_loader_20x)) 
real_input_shape = sample_images.shape 

print(f"Tamanho real do input obtido: {real_input_shape}")

for name in model_names_check:
    print(f"\n   ➤ MODELO: {name.upper()}")

    model_temp = get_model(name, num_classes=3, feature_extract=False)

    summary(
        model_temp,
        input_size=real_input_shape,
        col_names=["input_size", "output_size", "num_params", "mult_adds"],
        depth=1,
        verbose=1
    )

    del model_temp
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# /home/joyzinhw/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Tamanho real do input obtido: torch.Size([32, 3, 224, 224])
#
#    ➤ MODELO: RESNET50
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# ResNet                                   [32, 3, 224, 224]         [32, 3]                   --                        --
# ├─Conv2d: 1-1                            [32, 3, 224, 224]         [32, 64, 112, 112]        9,408                     3,776,446,464
# ├─BatchNorm2d: 1-2                       [32, 64, 112, 112]        [32, 64, 112, 112]        128                       4,096
# ├─ReLU: 1-3                              [32, 64, 112, 112]        [32, 64, 112, 112]        --                        --
# ├─MaxPool2d: 1-4                         [32, 64, 112, 112]        [32, 64, 56, 56]          --                        --
# ├─Sequential: 1-5                        [32, 64, 56, 56]          [32, 256, 56, 56]         215,808                   21,374,263,296
# ├─Sequential: 1-6                        [32, 256, 56, 56]         [32, 512, 28, 28]         1,219,584                 32,883,572,736
# ├─Sequential: 1-7                        [32, 512, 28, 28]         [32, 1024, 14, 14]        7,098,368                 46,859,419,648
# ├─Sequential: 1-8                        [32, 1024, 14, 14]        [32, 2048, 7, 7]          14,964,736                25,896,353,792
# ├─AdaptiveAvgPool2d: 1-9                 [32, 2048, 7, 7]          [32, 2048, 1, 1]          --                        --
# ├─Sequential: 1-10                       [32, 2048]                [32, 3]                   6,147                     196,704
# ============================================================================================================================================
# Total params: 23,514,179
# Trainable params: 23,514,179
# Non-trainable params: 0
# Total mult-adds (G): 130.79
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5690.36
# Params size (MB): 94.06
# Estimated Total Size (MB): 5803.68
# ============================================================================================================================================
#
#    ➤ MODELO: EFFICIENTNET_B0
# ===========================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Output Shape              Param #                   Mult-Adds
# ===========================================================================================================================================================
# EfficientNet                                            [32, 3, 224, 224]         [32, 3]                   --                        --
# ├─Sequential: 1-1                                       [32, 3, 224, 224]         [32, 1280, 7, 7]          4,007,548                 12,306,755,456
# ├─AdaptiveAvgPool2d: 1-2                                [32, 1280, 7, 7]          [32, 1280, 1, 1]          --                        --
# ├─Sequential: 1-3                                       [32, 1280]                [32, 3]                   3,843                     122,976
# ===========================================================================================================================================================
# Total params: 4,011,391
# Trainable params: 4,011,391
# Non-trainable params: 0
# Total mult-adds (G): 12.31
# ===========================================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.05
# Estimated Total Size (MB): 3487.41
# ===========================================================================================================================================================
#
#    ➤ MODELO: EFFICIENTNET_B3
# ===========================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Output Shape              Param #                   Mult-Adds
# ===========================================================================================================================================================
# EfficientNet                                            [32, 3, 224, 224]         [32, 3]                   --                        --
# ├─Sequential: 1-1                                       [32, 3, 224, 224]         [32, 1536, 7, 7]          10,696,232                30,760,947,712
# ├─AdaptiveAvgPool2d: 1-2                                [32, 1536, 7, 7]          [32, 1536, 1, 1]          --                        --
# ├─Sequential: 1-3                                       [32, 1536]                [32, 3]                   4,611                     147,552
# ===========================================================================================================================================================
# Total params: 10,700,843
# Trainable params: 10,700,843
# Non-trainable params: 0
# Total mult-adds (G): 30.76
# ===========================================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 6654.06
# Params size (MB): 42.80
# Estimated Total Size (MB): 6716.13
# ===========================================================================================================================================================
#
#    ➤ MODELO: DENSENET121
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# DenseNet                                 [32, 3, 224, 224]         [32, 3]                   --                        --
# ├─Sequential: 1-1                        [32, 3, 224, 224]         [32, 1024, 7, 7]          6,953,856                 90,663,081,984
# ├─Sequential: 1-2                        [32, 1024]                [32, 3]                   3,075                     98,400
# ============================================================================================================================================
# Total params: 6,956,931
# Trainable params: 6,956,931
# Non-trainable params: 0
# Total mult-adds (G): 90.66
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5777.06
# Params size (MB): 27.83
# Estimated Total Size (MB): 5824.16
# ============================================================================================================================================

# %%
# TRAIN 20X 
model_names = ['resnet50', 'efficientnet_b0', 'efficientnet_b3', 'densenet121']

results_20x = {}
histories_20x = {}
trained_models_20x = {}

loaders_20x = {'train': train_loader_20x, 'val': val_loader_20x}
criterion = nn.CrossEntropyLoss()

print(f">>> INICIANDO COMPARAÇÃO DOS 4 MODELOS NO DATASET 20X")
print(f"    Configuração: Épocas={num_epochs} | LR=3e-4 | Batch={batch_size}")
print("="*60)

for name in model_names:

    seed_everything(random_seed)
    print(f"\n[{name.upper()}] Inicializando modelo...")
    print(f"--- INICIANDO TREINAMENTO {name.upper()} ---")

    model = get_model(name, num_classes=3, feature_extract=False)

    save_path = f"best_{name}_20x.pth"

    
    model, hist, best_acc = train_model(
        model=model,
        dataloaders=loaders_20x,
        criterion=criterion,
        num_epochs=num_epochs,
        save_name=save_path,
        model_name=name.upper(),
        cutmix_prob=0.0,

       
        learning_rate=3e-4,
        weight_decay=1e-4,

        optimizer_name="adamw",
        scheduler_name="cosine",

        scheduler_t_max=35,
        min_learning_rate=1e-6,

     
        early_stopping_patience=20
    )
    
    results_20x[name] = best_acc
    histories_20x[name] = hist
    trained_models_20x[name] = model 


print("\n" + "="*60)
print("RESUMO DAS ACURÁCIAS (20X):")

for name, acc in results_20x.items():
    print(f"{name:<15}: {acc:.4f}")

print("="*60)
# Out:
# >>> INICIANDO COMPARAÇÃO DOS 4 MODELOS NO DATASET 20X
#     Configuração: Épocas=100 | LR=3e-4 | Batch=32
# ============================================================
#
# [RESNET50] Inicializando modelo...
# --- INICIANDO TREINAMENTO RESNET50 ---
#
# 🚀 START TRAINING RESNET50
# 🧠 Early Stopping patience = 20
#
# Epoch 01/100
#   TRAIN → Loss: 0.7654 | Acc: 0.6502
#   VAL → Loss: 0.6799 | Acc: 0.6667
#   BEST MODEL SAVED | Acc: 0.6667
#     LR atual: 0.000299
#
# Epoch 02/100
#   TRAIN → Loss: 0.3814 | Acc: 0.8555
#   VAL → Loss: 0.4149 | Acc: 0.8125
#   BEST MODEL SAVED | Acc: 0.8125
#     LR atual: 0.000298
#
# Epoch 03/100
#   TRAIN → Loss: 0.2570 | Acc: 0.8707
#   VAL → Loss: 0.5120 | Acc: 0.7292
#  No improvement for 1 epochs
#     LR atual: 0.000295
#
# Epoch 04/100
#   TRAIN → Loss: 0.2783 | Acc: 0.8935
#   VAL → Loss: 0.4808 | Acc: 0.8125
#  No improvement for 2 epochs
#     LR atual: 0.000290
#
# Epoch 05/100
#   TRAIN → Loss: 0.1732 | Acc: 0.9354
#   VAL → Loss: 0.2677 | Acc: 0.8958
#   BEST MODEL SAVED | Acc: 0.8958
#     LR atual: 0.000285
#
# Epoch 06/100
#   TRAIN → Loss: 0.1884 | Acc: 0.9240
#   VAL → Loss: 0.3263 | Acc: 0.8958
#  No improvement for 1 epochs
#     LR atual: 0.000279
#
# Epoch 07/100
#   TRAIN → Loss: 0.2359 | Acc: 0.9202
#   VAL → Loss: 0.1199 | Acc: 0.9583
#   BEST MODEL SAVED | Acc: 0.9583
#     LR atual: 0.000271
#
# Epoch 08/100
#   TRAIN → Loss: 0.1316 | Acc: 0.9506
#   VAL → Loss: 0.4929 | Acc: 0.8958
#  No improvement for 1 epochs
#     LR atual: 0.000263
#
# Epoch 09/100
#   TRAIN → Loss: 0.1871 | Acc: 0.9202
#   VAL → Loss: 0.8046 | Acc: 0.8750
#  No improvement for 2 epochs
#     LR atual: 0.000254
#
# Epoch 10/100
#   TRAIN → Loss: 0.2134 | Acc: 0.9240
#   VAL → Loss: 1.0825 | Acc: 0.8333
#  No improvement for 3 epochs
#     LR atual: 0.000244
#
# Epoch 11/100
#   TRAIN → Loss: 0.1601 | Acc: 0.9544
#   VAL → Loss: 0.3507 | Acc: 0.8750
#  No improvement for 4 epochs
#     LR atual: 0.000233
#
# Epoch 12/100
#   TRAIN → Loss: 0.1446 | Acc: 0.9468
#   VAL → Loss: 0.3175 | Acc: 0.8542
#  No improvement for 5 epochs
#     LR atual: 0.000221
#
# Epoch 13/100
#   TRAIN → Loss: 0.1083 | Acc: 0.9582
#   VAL → Loss: 0.4227 | Acc: 0.8750
#  No improvement for 6 epochs
#     LR atual: 0.000209
#
# Epoch 14/100
#   TRAIN → Loss: 0.1512 | Acc: 0.9468
#   VAL → Loss: 0.4724 | Acc: 0.7917
#  No improvement for 7 epochs
#     LR atual: 0.000197
#
# Epoch 15/100
#   TRAIN → Loss: 0.1662 | Acc: 0.9392
#   VAL → Loss: 0.5506 | Acc: 0.7708
#  No improvement for 8 epochs
#     LR atual: 0.000184
#
# Epoch 16/100
#   TRAIN → Loss: 0.1024 | Acc: 0.9658
#   VAL → Loss: 0.2896 | Acc: 0.8958
#  No improvement for 9 epochs
#     LR atual: 0.000171
#
# Epoch 17/100
#   TRAIN → Loss: 0.1136 | Acc: 0.9544
#   VAL → Loss: 0.2243 | Acc: 0.8333
#  No improvement for 10 epochs
#     LR atual: 0.000157
#
# Epoch 18/100
#   TRAIN → Loss: 0.1122 | Acc: 0.9620
#   VAL → Loss: 0.3523 | Acc: 0.8333
#  No improvement for 11 epochs
#     LR atual: 0.000144
#
# Epoch 19/100
#   TRAIN → Loss: 0.0601 | Acc: 0.9810
#   VAL → Loss: 0.3182 | Acc: 0.8542
#  No improvement for 12 epochs
#     LR atual: 0.000130
#
# Epoch 20/100
#   TRAIN → Loss: 0.0969 | Acc: 0.9582
#   VAL → Loss: 0.1697 | Acc: 0.8958
#  No improvement for 13 epochs
#     LR atual: 0.000117
#
# Epoch 21/100
#   TRAIN → Loss: 0.0678 | Acc: 0.9810
#   VAL → Loss: 0.1937 | Acc: 0.9375
#  No improvement for 14 epochs
#     LR atual: 0.000104
#
# Epoch 22/100
#   TRAIN → Loss: 0.0891 | Acc: 0.9620
#   VAL → Loss: 0.2293 | Acc: 0.9167
#  No improvement for 15 epochs
#     LR atual: 0.000092
#
# Epoch 23/100
#   TRAIN → Loss: 0.0838 | Acc: 0.9658
#   VAL → Loss: 0.3195 | Acc: 0.8958
#  No improvement for 16 epochs
#     LR atual: 0.000080
#
# Epoch 24/100
#   TRAIN → Loss: 0.1276 | Acc: 0.9354
#   VAL → Loss: 0.1938 | Acc: 0.8750
#  No improvement for 17 epochs
#     LR atual: 0.000068
#
# Epoch 25/100
#   TRAIN → Loss: 0.0716 | Acc: 0.9772
#   VAL → Loss: 0.2488 | Acc: 0.8958
#  No improvement for 18 epochs
#     LR atual: 0.000057
#
# Epoch 26/100
#   TRAIN → Loss: 0.0501 | Acc: 0.9810
#   VAL → Loss: 0.2169 | Acc: 0.9375
#  No improvement for 19 epochs
#     LR atual: 0.000047
#
# Epoch 27/100
#   TRAIN → Loss: 0.0660 | Acc: 0.9734
#   VAL → Loss: 0.1556 | Acc: 0.8958
#  No improvement for 20 epochs
#
#  EARLY STOPPING TRIGGERED (patience=20)
#
# Training complete in 32m 59s
#  Best Val Acc: 0.9583
#
# [EFFICIENTNET_B0] Inicializando modelo...
# --- INICIANDO TREINAMENTO EFFICIENTNET_B0 ---
#
# 🚀 START TRAINING EFFICIENTNET_B0
# 🧠 Early Stopping patience = 20
#
# Epoch 01/100
#   TRAIN → Loss: 0.7128 | Acc: 0.7034
#   VAL → Loss: 0.6552 | Acc: 0.6875
#   BEST MODEL SAVED | Acc: 0.6875
#     LR atual: 0.000299
#
# Epoch 02/100
#   TRAIN → Loss: 0.4006 | Acc: 0.8137
#   VAL → Loss: 0.4057 | Acc: 0.7917
#   BEST MODEL SAVED | Acc: 0.7917
#     LR atual: 0.000298
#
# Epoch 03/100
#   TRAIN → Loss: 0.2717 | Acc: 0.8897
#   VAL → Loss: 0.2694 | Acc: 0.8542
#   BEST MODEL SAVED | Acc: 0.8542
#     LR atual: 0.000295
#
# Epoch 04/100
#   TRAIN → Loss: 0.2131 | Acc: 0.9392
#   VAL → Loss: 0.2603 | Acc: 0.8542
#  No improvement for 1 epochs
#     LR atual: 0.000290
#
# Epoch 05/100
#   TRAIN → Loss: 0.2275 | Acc: 0.8821
#   VAL → Loss: 0.3016 | Acc: 0.8125
#  No improvement for 2 epochs
#     LR atual: 0.000285
#
# Epoch 06/100
#   TRAIN → Loss: 0.2144 | Acc: 0.9278
#   VAL → Loss: 0.3679 | Acc: 0.8125
#  No improvement for 3 epochs
#     LR atual: 0.000279
#
# Epoch 07/100
#   TRAIN → Loss: 0.1601 | Acc: 0.9392
#   VAL → Loss: 0.3380 | Acc: 0.8125
#  No improvement for 4 epochs
#     LR atual: 0.000271
#
# Epoch 08/100
#   TRAIN → Loss: 0.1722 | Acc: 0.9392
#   VAL → Loss: 0.2755 | Acc: 0.8333
#  No improvement for 5 epochs
#     LR atual: 0.000263
#
# Epoch 09/100
#   TRAIN → Loss: 0.0981 | Acc: 0.9658
#   VAL → Loss: 0.3359 | Acc: 0.8542
#  No improvement for 6 epochs
#     LR atual: 0.000254
#
# Epoch 10/100
#   TRAIN → Loss: 0.1366 | Acc: 0.9468
#   VAL → Loss: 0.4358 | Acc: 0.8125
#  No improvement for 7 epochs
#     LR atual: 0.000244
#
# Epoch 11/100
#   TRAIN → Loss: 0.1322 | Acc: 0.9468
#   VAL → Loss: 0.3099 | Acc: 0.8542
#  No improvement for 8 epochs
#     LR atual: 0.000233
#
# Epoch 12/100
#   TRAIN → Loss: 0.1082 | Acc: 0.9658
#   VAL → Loss: 0.7102 | Acc: 0.7917
#  No improvement for 9 epochs
#     LR atual: 0.000221
#
# Epoch 13/100
#   TRAIN → Loss: 0.1035 | Acc: 0.9658
#   VAL → Loss: 0.6364 | Acc: 0.8125
#  No improvement for 10 epochs
#     LR atual: 0.000209
#
# Epoch 14/100
#   TRAIN → Loss: 0.0955 | Acc: 0.9696
#   VAL → Loss: 0.3177 | Acc: 0.8333
#  No improvement for 11 epochs
#     LR atual: 0.000197
#
# Epoch 15/100
#   TRAIN → Loss: 0.0885 | Acc: 0.9734
#   VAL → Loss: 0.2194 | Acc: 0.8958
#   BEST MODEL SAVED | Acc: 0.8958
#     LR atual: 0.000184
#
# Epoch 16/100
#   TRAIN → Loss: 0.1596 | Acc: 0.9506
#   VAL → Loss: 0.3180 | Acc: 0.8333
#  No improvement for 1 epochs
#     LR atual: 0.000171
#
# Epoch 17/100
#   TRAIN → Loss: 0.0900 | Acc: 0.9696
#   VAL → Loss: 0.4789 | Acc: 0.8125
#  No improvement for 2 epochs
#     LR atual: 0.000157
#
# Epoch 18/100
#   TRAIN → Loss: 0.1063 | Acc: 0.9620
#   VAL → Loss: 0.5956 | Acc: 0.7917
#  No improvement for 3 epochs
#     LR atual: 0.000144
#
# Epoch 19/100
#   TRAIN → Loss: 0.0811 | Acc: 0.9772
#   VAL → Loss: 0.4841 | Acc: 0.8333
#  No improvement for 4 epochs
#     LR atual: 0.000130
#
# Epoch 20/100
#   TRAIN → Loss: 0.1009 | Acc: 0.9696
#   VAL → Loss: 0.3610 | Acc: 0.8333
#  No improvement for 5 epochs
#     LR atual: 0.000117
#
# Epoch 21/100
#   TRAIN → Loss: 0.0794 | Acc: 0.9696
#   VAL → Loss: 0.4662 | Acc: 0.8125
#  No improvement for 6 epochs
#     LR atual: 0.000104
#
# Epoch 22/100
#   TRAIN → Loss: 0.1057 | Acc: 0.9620
#   VAL → Loss: 0.5471 | Acc: 0.8125
#  No improvement for 7 epochs
#     LR atual: 0.000092
#
# Epoch 23/100
#   TRAIN → Loss: 0.0821 | Acc: 0.9810
#   VAL → Loss: 0.4907 | Acc: 0.8125
#  No improvement for 8 epochs
#     LR atual: 0.000080
#
# Epoch 24/100
#   TRAIN → Loss: 0.1122 | Acc: 0.9658
#   VAL → Loss: 0.4482 | Acc: 0.8125
#  No improvement for 9 epochs
#     LR atual: 0.000068
#
# Epoch 25/100
#   TRAIN → Loss: 0.1446 | Acc: 0.9468
#   VAL → Loss: 0.4981 | Acc: 0.8333
#  No improvement for 10 epochs
#     LR atual: 0.000057
#
# Epoch 26/100
#   TRAIN → Loss: 0.0689 | Acc: 0.9810
#   VAL → Loss: 0.5185 | Acc: 0.8333
#  No improvement for 11 epochs
#     LR atual: 0.000047
#
# Epoch 27/100
#   TRAIN → Loss: 0.0712 | Acc: 0.9772
#   VAL → Loss: 0.5373 | Acc: 0.8125
#  No improvement for 12 epochs
#     LR atual: 0.000038
#
# Epoch 28/100
#   TRAIN → Loss: 0.0665 | Acc: 0.9734
#   VAL → Loss: 0.5214 | Acc: 0.8333
#  No improvement for 13 epochs
#     LR atual: 0.000030
#
# Epoch 29/100
#   TRAIN → Loss: 0.0427 | Acc: 0.9924
#   VAL → Loss: 0.4225 | Acc: 0.8125
#  No improvement for 14 epochs
#     LR atual: 0.000022
#
# Epoch 30/100
#   TRAIN → Loss: 0.0642 | Acc: 0.9810
#   VAL → Loss: 0.3994 | Acc: 0.8333
#  No improvement for 15 epochs
#     LR atual: 0.000016
#
# Epoch 31/100
#   TRAIN → Loss: 0.0679 | Acc: 0.9772
#   VAL → Loss: 0.3796 | Acc: 0.8333
#  No improvement for 16 epochs
#     LR atual: 0.000011
#
# Epoch 32/100
#   TRAIN → Loss: 0.0714 | Acc: 0.9658
#   VAL → Loss: 0.3682 | Acc: 0.8333
#  No improvement for 17 epochs
#     LR atual: 0.000006
#
# Epoch 33/100
#   TRAIN → Loss: 0.0548 | Acc: 0.9848
#   VAL → Loss: 0.4138 | Acc: 0.8333
#  No improvement for 18 epochs
#     LR atual: 0.000003
#
# Epoch 34/100
#   TRAIN → Loss: 0.0459 | Acc: 0.9848
#   VAL → Loss: 0.4093 | Acc: 0.8333
#  No improvement for 19 epochs
#     LR atual: 0.000002
#
# Epoch 35/100
#   TRAIN → Loss: 0.0550 | Acc: 0.9848
#   VAL → Loss: 0.3593 | Acc: 0.8333
#  No improvement for 20 epochs
#
#  EARLY STOPPING TRIGGERED (patience=20)
#
# Training complete in 23m 41s
#  Best Val Acc: 0.8958
#
# [EFFICIENTNET_B3] Inicializando modelo...
# --- INICIANDO TREINAMENTO EFFICIENTNET_B3 ---
#
# 🚀 START TRAINING EFFICIENTNET_B3
# 🧠 Early Stopping patience = 20
#
# Epoch 01/100
#   TRAIN → Loss: 0.7980 | Acc: 0.6426
#   VAL → Loss: 0.6953 | Acc: 0.7500
#   BEST MODEL SAVED | Acc: 0.7500
#     LR atual: 0.000299
#
# Epoch 02/100
#   TRAIN → Loss: 0.4201 | Acc: 0.8327
#   VAL → Loss: 0.4593 | Acc: 0.7917
#   BEST MODEL SAVED | Acc: 0.7917
#     LR atual: 0.000298
#
# Epoch 03/100
#   TRAIN → Loss: 0.3789 | Acc: 0.8365
#   VAL → Loss: 0.3635 | Acc: 0.8125
#   BEST MODEL SAVED | Acc: 0.8125
#     LR atual: 0.000295
#
# Epoch 04/100
#   TRAIN → Loss: 0.2531 | Acc: 0.8897
#   VAL → Loss: 0.3084 | Acc: 0.8542
#   BEST MODEL SAVED | Acc: 0.8542
#     LR atual: 0.000290
#
# Epoch 05/100
#   TRAIN → Loss: 0.3327 | Acc: 0.8441
#   VAL → Loss: 0.2846 | Acc: 0.8958
#   BEST MODEL SAVED | Acc: 0.8958
#     LR atual: 0.000285
#
# Epoch 06/100
#   TRAIN → Loss: 0.2179 | Acc: 0.9125
#   VAL → Loss: 0.2088 | Acc: 0.8958
#  No improvement for 1 epochs
#     LR atual: 0.000279
#
# Epoch 07/100
#   TRAIN → Loss: 0.2147 | Acc: 0.9202
#   VAL → Loss: 0.2132 | Acc: 0.9375
#   BEST MODEL SAVED | Acc: 0.9375
#     LR atual: 0.000271
#
# Epoch 08/100
#   TRAIN → Loss: 0.1486 | Acc: 0.9506
#   VAL → Loss: 0.2517 | Acc: 0.9167
#  No improvement for 1 epochs
#     LR atual: 0.000263
#
# Epoch 09/100
#   TRAIN → Loss: 0.1634 | Acc: 0.9392
#   VAL → Loss: 0.2990 | Acc: 0.9167
#  No improvement for 2 epochs
#     LR atual: 0.000254
#
# Epoch 10/100
#   TRAIN → Loss: 0.1516 | Acc: 0.9316
#   VAL → Loss: 0.2687 | Acc: 0.9167
#  No improvement for 3 epochs
#     LR atual: 0.000244
#
# Epoch 11/100
#   TRAIN → Loss: 0.1450 | Acc: 0.9658
#   VAL → Loss: 0.2059 | Acc: 0.9167
#  No improvement for 4 epochs
#     LR atual: 0.000233
#
# Epoch 12/100
#   TRAIN → Loss: 0.1153 | Acc: 0.9430
#   VAL → Loss: 0.2332 | Acc: 0.9375
#  No improvement for 5 epochs
#     LR atual: 0.000221
#
# Epoch 13/100
#   TRAIN → Loss: 0.1702 | Acc: 0.9430
#   VAL → Loss: 0.3363 | Acc: 0.8958
#  No improvement for 6 epochs
#     LR atual: 0.000209
#
# Epoch 14/100
#   TRAIN → Loss: 0.0801 | Acc: 0.9772
#   VAL → Loss: 0.2648 | Acc: 0.8958
#  No improvement for 7 epochs
#     LR atual: 0.000197
#
# Epoch 15/100
#   TRAIN → Loss: 0.1043 | Acc: 0.9620
#   VAL → Loss: 0.2633 | Acc: 0.9167
#  No improvement for 8 epochs
#     LR atual: 0.000184
#
# Epoch 16/100
#   TRAIN → Loss: 0.0895 | Acc: 0.9696
#   VAL → Loss: 0.2585 | Acc: 0.9167
#  No improvement for 9 epochs
#     LR atual: 0.000171
#
# Epoch 17/100
#   TRAIN → Loss: 0.0567 | Acc: 0.9886
#   VAL → Loss: 0.2440 | Acc: 0.9375
#  No improvement for 10 epochs
#     LR atual: 0.000157
#
# Epoch 18/100
#   TRAIN → Loss: 0.1014 | Acc: 0.9506
#   VAL → Loss: 0.2322 | Acc: 0.9375
#  No improvement for 11 epochs
#     LR atual: 0.000144
#
# Epoch 19/100
#   TRAIN → Loss: 0.0587 | Acc: 0.9848
#   VAL → Loss: 0.3006 | Acc: 0.8958
#  No improvement for 12 epochs
#     LR atual: 0.000130
#
# Epoch 20/100
#   TRAIN → Loss: 0.0745 | Acc: 0.9658
#   VAL → Loss: 0.2155 | Acc: 0.9167
#  No improvement for 13 epochs
#     LR atual: 0.000117
#
# Epoch 21/100
#   TRAIN → Loss: 0.0624 | Acc: 0.9696
#   VAL → Loss: 0.1985 | Acc: 0.9583
#   BEST MODEL SAVED | Acc: 0.9583
#     LR atual: 0.000104
#
# Epoch 22/100
#   TRAIN → Loss: 0.0609 | Acc: 0.9734
#   VAL → Loss: 0.1873 | Acc: 0.9583
#  No improvement for 1 epochs
#     LR atual: 0.000092
#
# Epoch 23/100
#   TRAIN → Loss: 0.0704 | Acc: 0.9696
#   VAL → Loss: 0.2376 | Acc: 0.9375
#  No improvement for 2 epochs
#     LR atual: 0.000080
#
# Epoch 24/100
#   TRAIN → Loss: 0.0751 | Acc: 0.9696
#   VAL → Loss: 0.2239 | Acc: 0.9583
#  No improvement for 3 epochs
#     LR atual: 0.000068
#
# Epoch 25/100
#   TRAIN → Loss: 0.0674 | Acc: 0.9772
#   VAL → Loss: 0.2332 | Acc: 0.8958
#  No improvement for 4 epochs
#     LR atual: 0.000057
#
# Epoch 26/100
#   TRAIN → Loss: 0.0615 | Acc: 0.9772
#   VAL → Loss: 0.2541 | Acc: 0.9167
#  No improvement for 5 epochs
#     LR atual: 0.000047
#
# Epoch 27/100
#   TRAIN → Loss: 0.0537 | Acc: 0.9810
#   VAL → Loss: 0.2447 | Acc: 0.9167
#  No improvement for 6 epochs
#     LR atual: 0.000038
#
# Epoch 28/100
#   TRAIN → Loss: 0.0821 | Acc: 0.9620
#   VAL → Loss: 0.2157 | Acc: 0.9167
#  No improvement for 7 epochs
#     LR atual: 0.000030
#
# Epoch 29/100
#   TRAIN → Loss: 0.0597 | Acc: 0.9696
#   VAL → Loss: 0.2432 | Acc: 0.9375
#  No improvement for 8 epochs
#     LR atual: 0.000022
#
# Epoch 30/100
#   TRAIN → Loss: 0.0563 | Acc: 0.9734
#   VAL → Loss: 0.2396 | Acc: 0.9375
#  No improvement for 9 epochs
#     LR atual: 0.000016
#
# Epoch 31/100
#   TRAIN → Loss: 0.0470 | Acc: 0.9848
#   VAL → Loss: 0.2265 | Acc: 0.9583
#  No improvement for 10 epochs
#     LR atual: 0.000011
#
# Epoch 32/100
#   TRAIN → Loss: 0.0656 | Acc: 0.9772
#   VAL → Loss: 0.2608 | Acc: 0.9583
#  No improvement for 11 epochs
#     LR atual: 0.000006
#
# Epoch 33/100
#   TRAIN → Loss: 0.0490 | Acc: 0.9810
#   VAL → Loss: 0.2277 | Acc: 0.9375
#  No improvement for 12 epochs
#     LR atual: 0.000003
#
# Epoch 34/100
#   TRAIN → Loss: 0.0701 | Acc: 0.9772
#   VAL → Loss: 0.2333 | Acc: 0.9583
#  No improvement for 13 epochs
#     LR atual: 0.000002
#
# Epoch 35/100
#   TRAIN → Loss: 0.0734 | Acc: 0.9772
#   VAL → Loss: 0.2736 | Acc: 0.9375
#  No improvement for 14 epochs
#     LR atual: 0.000001
#
# Epoch 36/100
#   TRAIN → Loss: 0.0417 | Acc: 0.9886
#   VAL → Loss: 0.2273 | Acc: 0.9583
#  No improvement for 15 epochs
#     LR atual: 0.000002
#
# Epoch 37/100
#   TRAIN → Loss: 0.0452 | Acc: 0.9848
#   VAL → Loss: 0.2028 | Acc: 0.9375
#  No improvement for 16 epochs
#     LR atual: 0.000003
#
# Epoch 38/100
#   TRAIN → Loss: 0.0695 | Acc: 0.9734
#   VAL → Loss: 0.2036 | Acc: 0.9375
#  No improvement for 17 epochs
#     LR atual: 0.000006
#
# Epoch 39/100
#   TRAIN → Loss: 0.1005 | Acc: 0.9658
#   VAL → Loss: 0.1984 | Acc: 0.9167
#  No improvement for 18 epochs
#     LR atual: 0.000011
#
# Epoch 40/100
#   TRAIN → Loss: 0.0503 | Acc: 0.9734
#   VAL → Loss: 0.1958 | Acc: 0.9375
#  No improvement for 19 epochs
#     LR atual: 0.000016
#
# Epoch 41/100
#   TRAIN → Loss: 0.0560 | Acc: 0.9772
#   VAL → Loss: 0.2164 | Acc: 0.9583
#  No improvement for 20 epochs
#
#  EARLY STOPPING TRIGGERED (patience=20)
#
# Training complete in 53m 36s
#  Best Val Acc: 0.9583
#
# [DENSENET121] Inicializando modelo...
# --- INICIANDO TREINAMENTO DENSENET121 ---
#
# 🚀 START TRAINING DENSENET121
# 🧠 Early Stopping patience = 20
#
# Epoch 01/100
#   TRAIN → Loss: 0.6151 | Acc: 0.7262
#   VAL → Loss: 0.4117 | Acc: 0.8125
#   BEST MODEL SAVED | Acc: 0.8125
#     LR atual: 0.000299
#
# Epoch 02/100
#   TRAIN → Loss: 0.3189 | Acc: 0.8669
#   VAL → Loss: 1.0892 | Acc: 0.7083
#  No improvement for 1 epochs
#     LR atual: 0.000298
#
# Epoch 03/100
#   TRAIN → Loss: 0.2975 | Acc: 0.8669
#   VAL → Loss: 0.7076 | Acc: 0.7708
#  No improvement for 2 epochs
#     LR atual: 0.000295
#
# Epoch 04/100
#   TRAIN → Loss: 0.2398 | Acc: 0.8859
#   VAL → Loss: 0.3047 | Acc: 0.8958
#   BEST MODEL SAVED | Acc: 0.8958
#     LR atual: 0.000290
#
# Epoch 05/100
#   TRAIN → Loss: 0.2520 | Acc: 0.9125
#   VAL → Loss: 0.3974 | Acc: 0.8333
#  No improvement for 1 epochs
#     LR atual: 0.000285
#
# Epoch 06/100
#   TRAIN → Loss: 0.2931 | Acc: 0.8935
#   VAL → Loss: 0.6623 | Acc: 0.7708
#  No improvement for 2 epochs
#     LR atual: 0.000279
#
# Epoch 07/100
#   TRAIN → Loss: 0.2278 | Acc: 0.8973
#   VAL → Loss: 0.3743 | Acc: 0.8958
#  No improvement for 3 epochs
#     LR atual: 0.000271
#
# Epoch 08/100
#   TRAIN → Loss: 0.1786 | Acc: 0.9354
#   VAL → Loss: 0.4360 | Acc: 0.7917
#  No improvement for 4 epochs
#     LR atual: 0.000263
#
# Epoch 09/100
#   TRAIN → Loss: 0.2789 | Acc: 0.8935
#   VAL → Loss: 0.3791 | Acc: 0.7708
#  No improvement for 5 epochs
#     LR atual: 0.000254
#
# Epoch 10/100
#   TRAIN → Loss: 0.1346 | Acc: 0.9392
#   VAL → Loss: 0.4568 | Acc: 0.8125
#  No improvement for 6 epochs
#     LR atual: 0.000244
#
# Epoch 11/100
#   TRAIN → Loss: 0.1579 | Acc: 0.9278
#   VAL → Loss: 0.4804 | Acc: 0.8125
#  No improvement for 7 epochs
#     LR atual: 0.000233
#
# Epoch 12/100
#   TRAIN → Loss: 0.1187 | Acc: 0.9620
#   VAL → Loss: 0.3113 | Acc: 0.8333
#  No improvement for 8 epochs
#     LR atual: 0.000221
#
# Epoch 13/100
#   TRAIN → Loss: 0.1334 | Acc: 0.9468
#   VAL → Loss: 0.2781 | Acc: 0.8750
#  No improvement for 9 epochs
#     LR atual: 0.000209
#
# Epoch 14/100
#   TRAIN → Loss: 0.1686 | Acc: 0.9354
#   VAL → Loss: 0.2818 | Acc: 0.8333
#  No improvement for 10 epochs
#     LR atual: 0.000197
#
# Epoch 15/100
#   TRAIN → Loss: 0.1554 | Acc: 0.9506
#   VAL → Loss: 0.3199 | Acc: 0.8125
#  No improvement for 11 epochs
#     LR atual: 0.000184
#
# Epoch 16/100
#   TRAIN → Loss: 0.1290 | Acc: 0.9468
#   VAL → Loss: 0.2505 | Acc: 0.8958
#  No improvement for 12 epochs
#     LR atual: 0.000171
#
# Epoch 17/100
#   TRAIN → Loss: 0.1219 | Acc: 0.9582
#   VAL → Loss: 0.2450 | Acc: 0.8958
#  No improvement for 13 epochs
#     LR atual: 0.000157
#
# Epoch 18/100
#   TRAIN → Loss: 0.1416 | Acc: 0.9468
#   VAL → Loss: 0.2132 | Acc: 0.9167
#   BEST MODEL SAVED | Acc: 0.9167
#     LR atual: 0.000144
#
# Epoch 19/100
#   TRAIN → Loss: 0.1394 | Acc: 0.9354
#   VAL → Loss: 0.3990 | Acc: 0.8542
#  No improvement for 1 epochs
#     LR atual: 0.000130
#
# Epoch 20/100
#   TRAIN → Loss: 0.1362 | Acc: 0.9544
#   VAL → Loss: 0.3369 | Acc: 0.8750
#  No improvement for 2 epochs
#     LR atual: 0.000117
#
# Epoch 21/100
#   TRAIN → Loss: 0.1565 | Acc: 0.9240
#   VAL → Loss: 0.2622 | Acc: 0.8333
#  No improvement for 3 epochs
#     LR atual: 0.000104
#
# Epoch 22/100
#   TRAIN → Loss: 0.0930 | Acc: 0.9696
#   VAL → Loss: 0.3030 | Acc: 0.8333
#  No improvement for 4 epochs
#     LR atual: 0.000092
#
# Epoch 23/100
#   TRAIN → Loss: 0.1150 | Acc: 0.9316
#   VAL → Loss: 0.3843 | Acc: 0.7917
#  No improvement for 5 epochs
#     LR atual: 0.000080
#
# Epoch 24/100
#   TRAIN → Loss: 0.0943 | Acc: 0.9734
#   VAL → Loss: 0.4062 | Acc: 0.8125
#  No improvement for 6 epochs
#     LR atual: 0.000068
#
# Epoch 25/100
#   TRAIN → Loss: 0.0736 | Acc: 0.9848
#   VAL → Loss: 0.3422 | Acc: 0.8750
#  No improvement for 7 epochs
#     LR atual: 0.000057
#
# Epoch 26/100
#   TRAIN → Loss: 0.0961 | Acc: 0.9696
#   VAL → Loss: 0.2375 | Acc: 0.8958
#  No improvement for 8 epochs
#     LR atual: 0.000047
#
# Epoch 27/100
#   TRAIN → Loss: 0.0959 | Acc: 0.9658
#   VAL → Loss: 0.3559 | Acc: 0.8542
#  No improvement for 9 epochs
#     LR atual: 0.000038
#
# Epoch 28/100
#   TRAIN → Loss: 0.0519 | Acc: 0.9886
#   VAL → Loss: 0.3701 | Acc: 0.8333
#  No improvement for 10 epochs
#     LR atual: 0.000030
#
# Epoch 29/100
#   TRAIN → Loss: 0.0995 | Acc: 0.9620
#   VAL → Loss: 0.1738 | Acc: 0.9167
#  No improvement for 11 epochs
#     LR atual: 0.000022
#
# Epoch 30/100
#   TRAIN → Loss: 0.0812 | Acc: 0.9620
#   VAL → Loss: 0.2708 | Acc: 0.8750
#  No improvement for 12 epochs
#     LR atual: 0.000016
#
# Epoch 31/100
#   TRAIN → Loss: 0.0493 | Acc: 0.9924
#   VAL → Loss: 0.2619 | Acc: 0.8750
#  No improvement for 13 epochs
#     LR atual: 0.000011
#
# Epoch 32/100
#   TRAIN → Loss: 0.0798 | Acc: 0.9734
#   VAL → Loss: 0.2202 | Acc: 0.9167
#  No improvement for 14 epochs
#     LR atual: 0.000006
#
# Epoch 33/100
#   TRAIN → Loss: 0.0558 | Acc: 0.9772
#   VAL → Loss: 0.2760 | Acc: 0.8542
#  No improvement for 15 epochs
#     LR atual: 0.000003
#
# Epoch 34/100
#   TRAIN → Loss: 0.0913 | Acc: 0.9696
#   VAL → Loss: 0.3341 | Acc: 0.8542
#  No improvement for 16 epochs
#     LR atual: 0.000002
#
# Epoch 35/100
#   TRAIN → Loss: 0.0404 | Acc: 0.9886
#   VAL → Loss: 0.2040 | Acc: 0.9167
#  No improvement for 17 epochs
#     LR atual: 0.000001
#
# Epoch 36/100
#   TRAIN → Loss: 0.0724 | Acc: 0.9696
#   VAL → Loss: 0.3592 | Acc: 0.8333
#  No improvement for 18 epochs
#     LR atual: 0.000002
#
# Epoch 37/100
#   TRAIN → Loss: 0.0525 | Acc: 0.9810
#   VAL → Loss: 0.2928 | Acc: 0.8542
#  No improvement for 19 epochs
#     LR atual: 0.000003
#
# Epoch 38/100
#   TRAIN → Loss: 0.0445 | Acc: 0.9848
#   VAL → Loss: 0.3064 | Acc: 0.8333
#  No improvement for 20 epochs
#
#  EARLY STOPPING TRIGGERED (patience=20)
#
# Training complete in 47m 35s
#  Best Val Acc: 0.9167
#
# ============================================================
# RESUMO DAS ACURÁCIAS (20X):
# resnet50       : 0.9583
# efficientnet_b0: 0.8958
# efficientnet_b3: 0.9583
# densenet121    : 0.9167
# ============================================================

# %%
# TRAIN 40X 
model_names = ['resnet50', 'efficientnet_b0', 'efficientnet_b3', 'densenet121']

results_40x = {}
histories_40x = {}
trained_models_40x = {}

loaders_40x = {'train': train_loader_40x, 'val': val_loader_40x}
criterion = nn.CrossEntropyLoss()

print(f">>> INICIANDO COMPARAÇÃO DOS 4 MODELOS NO DATASET 40X")
print(f"    Configuração: Épocas={num_epochs} | LR=3e-4 | Batch={batch_size}")
print("="*60)

for name in model_names:
    seed_everything(random_seed)
    print(f"\n[{name.upper()}] Inicializando modelo...")
    print(f"--- INICIANDO TREINAMENTO {name.upper()} ---")
    
    model = get_model(name, num_classes=3, feature_extract=False)

    save_path = f"best_{name}_40x.pth"

    model, hist, best_acc = train_model(
        model=model,
        dataloaders=loaders_40x,
        criterion=criterion,
        num_epochs=num_epochs,
        save_name=save_path,
        model_name=name.upper(),
        cutmix_prob=0.0,

       
        learning_rate=3e-4,
        weight_decay=1e-4,

        optimizer_name="adamw",
        scheduler_name="cosine",

        scheduler_t_max=35,
        min_learning_rate=1e-6,

     
        early_stopping_patience=20
    )
    
    results_40x[name] = best_acc
    histories_40x[name] = hist
    trained_models_40x[name] = model

# ====================== RESULTADOS ======================
print("\n" + "="*60)
print("RESUMO DAS ACURÁCIAS (40X):")

for name, acc in results_40x.items():
    print(f"{name:<15}: {acc:.4f}")

print("="*60)
# Out:
# >>> INICIANDO COMPARAÇÃO DOS 4 MODELOS NO DATASET 40X
#     Configuração: Épocas=100 | LR=3e-4 | Batch=32
# ============================================================
#
# [RESNET50] Inicializando modelo...
# --- INICIANDO TREINAMENTO RESNET50 ---
#
# 🚀 START TRAINING RESNET50
# 🧠 Early Stopping patience = 20
#
# Epoch 01/100
# /home/joyzinhw/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#   TRAIN → Loss: 0.8068 | Acc: 0.6737
#   VAL → Loss: 0.6684 | Acc: 0.8913
#   BEST MODEL SAVED | Acc: 0.8913
#     LR atual: 0.000299
#
# Epoch 02/100

# %%
# ====================== PARTE 11: GRÁFICOS ======================
def plot_line_chart_comparison(histories, title_suffix=""):
    sns.set_style("whitegrid") 
    colors = ['#1f77b4', '#d62728', '#2ca02c', '#ff7f0e', '#9467bd']
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # ====================== ACCURACY ======================
    ax1 = axes[0]
    for i, (name, hist) in enumerate(histories.items()):
        val_acc = hist['val_acc']
        epochs = range(1, len(val_acc) + 1)

        ax1.plot(
            epochs,
            val_acc,
            label=name,
            color=colors[i % len(colors)],
            linewidth=1.5,
            linestyle='-',
            alpha=0.9
        )

        best_val = max(val_acc)
        best_epoch = val_acc.index(best_val) + 1

        ax1.scatter(
            best_epoch,
            best_val,
            s=150,
            c=colors[i],
            edgecolors='k',
            zorder=10
        )

    ax1.set_title(f'ACC: VAL {title_suffix}', fontsize=14, fontweight='bold', color='#333333')
    ax1.set_xlabel('Épocas', fontsize=12)
    ax1.set_ylabel('Acurácia', fontsize=12)
    ax1.legend(fontsize=11, frameon=True, fancybox=True, shadow=True)

    # ====================== LOSS ======================
    ax2 = axes[1]
    for i, (name, hist) in enumerate(histories.items()):
        val_loss = hist['val_loss']
        epochs = range(1, len(val_loss) + 1)

        ax2.plot(
            epochs,
            val_loss,
            label=name,
            color=colors[i % len(colors)],
            linewidth=1.5,
            linestyle='-',
            alpha=0.9
        )

        min_loss = min(val_loss)
        best_epoch_loss = val_loss.index(min_loss) + 1

        ax2.scatter(
            best_epoch_loss,
            min_loss,
            s=150,
            c=colors[i],
            edgecolors='k',
            zorder=10
        )

    ax2.set_title(f'LOSS: VAL {title_suffix}', fontsize=14, fontweight='bold', color='#333333')
    ax2.set_xlabel('Épocas', fontsize=12)
    ax2.set_ylabel('Loss', fontsize=12)
    ax2.legend(fontsize=11, frameon=True, fancybox=True, shadow=True)

    plt.tight_layout()
    plt.subplots_adjust(wspace=0.3)
    plt.show()


print(f"GRÁFICO DE COMPARAÇÃO DO DATASET 20X")
plot_line_chart_comparison(histories_20x, title_suffix="(Dataset 20X)")

print(f"\n\nGRÁFICO DE COMPARAÇÃO DO DATASET 40X")
plot_line_chart_comparison(histories_40x, title_suffix="(Dataset 40X)")
# Out:
# GRÁFICO DE COMPARAÇÃO DO DATASET 20X
# GRÁFICO DE COMPARAÇÃO DO DATASET 40X

# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import (
    accuracy_score,
    cohen_kappa_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

def evaluate_model_full(
    model,
    loader,
    model_name,
    class_names=['ACA', 'SCC', 'NOR'],
    save_dir="results"
):
    model.eval()
    y_true = []
    y_pred = []
    y_probs = []

    print(f"\nRELATÓRIO: {model_name.upper()}")

    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)

        
            outputs = torch.nan_to_num(outputs, nan=0.0, posinf=10.0, neginf=-10.0)

            _, preds = torch.max(outputs, 1)
            probs = F.softmax(outputs, dim=1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
            y_probs.extend(probs.cpu().numpy())

    y_probs = np.array(y_probs)

    
    y_probs = np.nan_to_num(y_probs, nan=1.0/len(class_names))

    
    acc = accuracy_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)

    try:
        labels_index = list(range(len(class_names)))

        roc_auc = roc_auc_score(
            y_true,
            y_probs,
            multi_class='ovr',
            average='macro',
            labels=labels_index
        )

    except Exception as e:
        print(f"ERRO ROC-AUC: {e}")
        print(f"(Shape y_probs: {y_probs.shape} | Classes únicas em y_true: {np.unique(y_true)})")
        roc_auc = 0.0

    print(f"➤ RESULTADO: Accuracy: {acc:.4f} | ROC-AUC: {roc_auc:.4f} | Kappa: {kappa:.4f}\n")

    print("RELATÓRIO DE CLASSIFICAÇÃO:")
    print(classification_report(
        y_true,
        y_pred,
        target_names=class_names,
        digits=4,
        zero_division=0
    ))

    
    cm = confusion_matrix(y_true, y_pred)

    print("\nMATRIZ DE CONFUSÃO:")
    print(cm)

    
    os.makedirs(save_dir, exist_ok=True)

    
    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.title(f"Matriz de Confusão - {model_name}")
    plt.tight_layout()
    plt.savefig(f"{save_dir}/cm_{model_name}.png", dpi=300)
    plt.close()

    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm_norm,
        annot=True,
        fmt='.2f',
        cmap='Blues',
        xticklabels=class_names,
        yticklabels=class_names
    )
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.title(f"Matriz Normalizada - {model_name}")
    plt.tight_layout()
    plt.savefig(f"{save_dir}/cm_norm_{model_name}.png", dpi=300)
    plt.close()

    print(f"✔ Matrizes salvas em: {save_dir}/")

    print("-" * 85)

    return acc, roc_auc, kappa, cm

# %%
print("RESULTADOS DA AVALIAÇÃO (DATASET 20X)")

for name, model in trained_models_20x.items():
    evaluate_model_full(model, test_loader_20x, f"{name}")
# Out:
# KẾT QUẢ ĐÁNH GIÁ (DATASET 20X)
#
# RELATÓRIO: RESNET50
# ➤ RESULTADO: Accuracy: 1.0000 | ROC-AUC: 1.0000 | Kappa: 1.0000
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     1.0000    1.0000    1.0000        18
#          SCC     1.0000    1.0000    1.0000        11
#          NOR     1.0000    1.0000    1.0000        19
#
#     accuracy                         1.0000        48
#    macro avg     1.0000    1.0000    1.0000        48
# weighted avg     1.0000    1.0000    1.0000        48
#
#
# MATRIZ DE CONFUSÃO:
# [[18  0  0]
#  [ 0 11  0]
#  [ 0  0 19]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: EFFICIENTNET_B0
# ➤ RESULTADO: Accuracy: 0.7917 | ROC-AUC: 0.9811 | Kappa: 0.6813
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.6538    0.9444    0.7727        18
#          SCC     1.0000    1.0000    1.0000        11
#          NOR     0.9091    0.5263    0.6667        19
#
#     accuracy                         0.7917        48
#    macro avg     0.8543    0.8236    0.8131        48
# weighted avg     0.8342    0.7917    0.7828        48
#
#
# MATRIZ DE CONFUSÃO:
# [[17  0  1]
#  [ 0 11  0]
#  [ 9  0 10]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: EFFICIENTNET_B3
# ➤ RESULTADO: Accuracy: 0.8333 | ROC-AUC: 0.9731 | Kappa: 0.7443
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.7273    0.8889    0.8000        18
#          SCC     1.0000    1.0000    1.0000        11
#          NOR     0.8667    0.6842    0.7647        19
#
#     accuracy                         0.8333        48
#    macro avg     0.8646    0.8577    0.8549        48
# weighted avg     0.8449    0.8333    0.8319        48
#
#
# MATRIZ DE CONFUSÃO:
# [[16  0  2]
#  [ 0 11  0]
#  [ 6  0 13]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: DENSENET121
# ➤ RESULTADO: Accuracy: 0.9167 | ROC-AUC: 0.9853 | Kappa: 0.8720
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.8500    0.9444    0.8947        18
#          SCC     1.0000    1.0000    1.0000        11
#          NOR     0.9412    0.8421    0.8889        19
#
#     accuracy                         0.9167        48
#    macro avg     0.9304    0.9288    0.9279        48
# weighted avg     0.9205    0.9167    0.9165        48
#
#
# MATRIZ DE CONFUSÃO:
# [[17  0  1]
#  [ 0 11  0]
#  [ 3  0 16]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------

# %%
print("RESULTADOS DA AVALIAÇÃO (DATASET 40X)")
for name, model in trained_models_40x.items(): evaluate_model_full(model, test_loader_40x, f"{name}")
# Out:
# KẾT QUẢ ĐÁNH GIÁ (DATASET 40X)
#
# RELATÓRIO: RESNET50
# ➤ RESULTADO: Accuracy: 0.8800 | ROC-AUC: 0.9910 | Kappa: 0.8146
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.7391    1.0000    0.8500        17
#          SCC     1.0000    1.0000    1.0000        20
#          NOR     1.0000    0.5385    0.7000        13
#
#     accuracy                         0.8800        50
#    macro avg     0.9130    0.8462    0.8500        50
# weighted avg     0.9113    0.8800    0.8710        50
#
#
# MATRIZ DE CONFUSÃO:
# [[17  0  0]
#  [ 0 20  0]
#  [ 6  0  7]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: EFFICIENTNET_B0
# ➤ RESULTADO: Accuracy: 0.9400 | ROC-AUC: 0.9949 | Kappa: 0.9089
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.9375    0.8824    0.9091        17
#          SCC     1.0000    1.0000    1.0000        20
#          NOR     0.8571    0.9231    0.8889        13
#
#     accuracy                         0.9400        50
#    macro avg     0.9315    0.9351    0.9327        50
# weighted avg     0.9416    0.9400    0.9402        50
#
#
# MATRIZ DE CONFUSÃO:
# [[15  0  2]
#  [ 0 20  0]
#  [ 1  0 12]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: EFFICIENTNET_B3
# ➤ RESULTADO: Accuracy: 0.9400 | ROC-AUC: 0.9910 | Kappa: 0.9084
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     0.8889    0.9412    0.9143        17
#          SCC     1.0000    1.0000    1.0000        20
#          NOR     0.9167    0.8462    0.8800        13
#
#     accuracy                         0.9400        50
#    macro avg     0.9352    0.9291    0.9314        50
# weighted avg     0.9406    0.9400    0.9397        50
#
#
# MATRIZ DE CONFUSÃO:
# [[16  0  1]
#  [ 0 20  0]
#  [ 2  0 11]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
#
# RELATÓRIO: DENSENET121
# ➤ RESULTADO: Accuracy: 1.0000 | ROC-AUC: 1.0000 | Kappa: 1.0000
#
# RELATÓRIO DE CLASSIFICAÇÃO:
#               precision    recall  f1-score   support
#
#          ACA     1.0000    1.0000    1.0000        17
#          SCC     1.0000    1.0000    1.0000        20
#          NOR     1.0000    1.0000    1.0000        13
#
#     accuracy                         1.0000        50
#    macro avg     1.0000    1.0000    1.0000        50
# weighted avg     1.0000    1.0000    1.0000        50
#
#
# MATRIZ DE CONFUSÃO:
# [[17  0  0]
#  [ 0 20  0]
#  [ 0  0 13]]
# ✔ Matrizes salvas em: results/
# -------------------------------------------------------------------------------------
